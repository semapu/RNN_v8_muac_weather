# %%
"""
Autohr: Sergi Mas Pujol
Last update: 14/06/2021

Python version: 3.6
"""
# Out:
# '\nAutohr: Sergi Mas Pujol\nLast update: 14/06/2021\n\nPython version: 3.6\n'

# %%
import numpy as np
np.random.seed(4)
import sys
import math
import random
random.seed(7)
from random import sample
from datetime import datetime, timedelta, date

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 7]

from utils_samplesTraining import read_REGULATIONS_file
from utils_timeProcessing import from_YYYYMMDDHHMMSS_to_HHMMSS_withTwoDots, \
                                 substract_minutes_given_HHSSMM, add_minutes_given_HHSSMM, \
                                 from_YYYYMMDD_to_DDMMYYYY_given_separator, \
                                 listDays_betweenTwoDates, \
                                 from_YYYYMMDDHHMMSS_to_HHMMSS, \
                                 from_HHMMSS_to_HH                                 
from utils_samplesTraining import readAssociatedFile_fromAIRAC_givenDate, \
                                  extract_regulations,\
                                  addIntervals_toFinalConjunt, \
                                  compute_start_end_timestamps_from_days_with_regulations
from generator import extract_features_from_list_days_and_timestamps, \
                      extract_days_timestamps_volumes_labels_days_with_regulations

from generator_weather import extract_weather_information_from_list_days_and_timestamps

# %%
from keras.models import Model
from keras.layers import Dense, Input, Dropout, LSTM, Activation, TimeDistributed
# from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.initializers import glorot_uniform

# %%
# Given the start timestamp of the regulation -> Considered time before and after
# Temporal gaps in minutes
gap_before_start_time = 0
gap_after_start_time = 30

# %%
num_epochs = 300
batch_size = 32

# %%
num_weather_features = 16
num_metric_per_weather_feature = 3

# %% [markdown]
# # Prepare / Extreact data

# %% [markdown]
# ###  Extract the available regulations

# %%
REGULATIONS = read_REGULATIONS_file('./20190604_20191020_REGULATIONS.csv')

"""
If the regulation contains a cancel_time -> It will be ignored
    * To take them into account -> Remove last condition
"""
REGULATIONS = REGULATIONS.loc[(REGULATIONS["regulation_reason"].isin([' W-Weather '])) & 
                              (REGULATIONS["location_type"] == ' En route ') &
                              (REGULATIONS["cancel_time"] == '  ')
                             ]

# %%
# TODO: Try to optimaze the following step (very slow)

# Drop all the regulations which are not associated to a "traffic_volume" == "MAS..."
count_drops = 0
for index, row in REGULATIONS.iterrows():
    
    # The .strip() is requieres because there is a white space at the beginning of the names
    if row["traffic_volume"].strip()[0:3] != 'MAS': 
        REGULATIONS = REGULATIONS.drop(index=index)
        count_drops += 1

# %%
print('Number ALL regulations from the given sector: ', str(len(REGULATIONS.values)))
# Out:
# Number ALL regulations from the given sector:  151

# %%
# ".strip() -> Remove all the white spaaces in the timestamp"

REGULATIONS.loc[:, 'date_DDMMYYYY'] = REGULATIONS.apply(lambda x: from_YYYYMMDD_to_DDMMYYYY_given_separator(x.target_date.strip(), '/'), axis=1)

REGULATIONS.loc[:, 'start_time_HHMMSS'] = REGULATIONS.apply(lambda x: from_YYYYMMDDHHMMSS_to_HHMMSS_withTwoDots(x.start_time.strip()), axis=1)
REGULATIONS.loc[:, 'end_time_HHMMSS'] = REGULATIONS.apply(lambda x: from_YYYYMMDDHHMMSS_to_HHMMSS_withTwoDots(x.end_time.strip()), axis=1)
REGULATIONS.loc[:, 'start_time_study_HHMMSS'] = REGULATIONS.apply(lambda x: substract_minutes_given_HHSSMM(x.start_time_HHMMSS, gap_before_start_time), axis=1)
REGULATIONS.loc[:, 'end_time_study_HHMMSS'] = REGULATIONS.apply(lambda x: add_minutes_given_HHSSMM(x.start_time_HHMMSS, gap_after_start_time), axis=1)

# %%
# We want to remove from the DataFrame all the rows outside the valid interval of days
# Outside the date of the available AIRACS
min_date = date(2019, 6, 4)
# max_date = date(2019, 8, 14) 
max_date = date(2019, 9, 11) 


for index, row in REGULATIONS.iterrows():
        
    date_split = row["date_DDMMYYYY"].split("/") # 0 -> day; 1 -> month; 2 -> year
    date_object = date(int(date_split[2]), int(date_split[1]), int(date_split[0]))
    
    # Check if the regulation's date belong to the valid interval -> IF outside, drop the Regulation
    if date_object < min_date or date_object > max_date:
        REGULATIONS = REGULATIONS.drop(index=index)

# %%
print('Number regulations AFTER pre-processing: ', str(len(REGULATIONS.values)))
# Out:
# Number regulations AFTER pre-processing:  139

# %%
# Count all the available regulations per TV
instances_count = dict()
for volume in REGULATIONS['traffic_volume'].values:
    if volume in instances_count.keys():
        instances_count[volume] += 1
    else:
        instances_count[volume] = 1

# %% [markdown]
# ### Extract the different list of days and timestamps

# %% [markdown]
# ##### Samples without regulations from days without regulations

# %%
# Extract the days with regulations
list_days_with_regulations = REGULATIONS["date_DDMMYYYY"].values

# Initialize a list with all the possible days and the final list for the days without regulations
list_all_possible_days = listDays_betweenTwoDates(min_date, max_date, 'DDMMYYYY', '/')
list_days_without_regulations = list()

# %%
# If a day does not appear in the list with reguilations -> No regulations for that day
for day in list_all_possible_days:
    if day not in list_days_with_regulations:
        list_days_without_regulations.append(day)

# %%
# For the days without regulations, we will generate random timestamps

list_days_without_regulations_extended = list()
start_time_samples_no_regulations = list()
end_time_samples_no_regulations = list()
list_volumes_no_regulations = list()

for day in list_days_without_regulations:
    # Iterate multiple time each day without regulations
    for _ in range(0,1):
        # Randomly create the hour and the minutes
        hour = str("{:02d}".format(random.randint(3,21))) # From 2 to 22 to avoid extrems (wrap around timestamps)
        minute = str("{:02d}".format(random.randint(0,59)))

        # Create the timestamp
        random_timestamps = hour + ":" + minute + ":" + '00'

        # Substract a given about to create the starting timestamp
        start_timestamp = substract_minutes_given_HHSSMM(random_timestamps, gap_before_start_time)
        start_time_samples_no_regulations.append(start_timestamp)

        # Add a given about to create the ending timestamp
        end_timestamp = add_minutes_given_HHSSMM(random_timestamps, gap_after_start_time)
        end_time_samples_no_regulations.append(end_timestamp)

        # Due to no regulations were createcd for the given day, randomly select a volume
        index_random_volume = random.randint(0, REGULATIONS["traffic_volume"].values.shape[0]-1)
        random_volume = REGULATIONS.iloc[index_random_volume]["traffic_volume"][4:8] # To only save the suffix

        # Some "traffic_volumes" in the REGULATIONS file has different names than the "locations".
        # To avoid this error, we will manually parse this cases
        if random_volume == 'BALB':
            random_volume = 'BLUX'
    
        list_days_without_regulations_extended.append(day)
        list_volumes_no_regulations.append(random_volume)

# %%
len(list_days_without_regulations_extended), len(start_time_samples_no_regulations), \
len(end_time_samples_no_regulations), len(list_volumes_no_regulations)
# Out:
# (71, 71, 71, 71)

# %% [markdown]
# ##### Sample with & without regulations from days with regulations completly random
# ##### It is possible ta have sample with both categories (e.g. start NO Regs from Regs and then Reg)

# %%
REGULATIONS.loc[:, 'start_regulations_HHMMSS'] = REGULATIONS.apply(lambda x: from_YYYYMMDDHHMMSS_to_HHMMSS(x.start_time.strip()), axis=1)
REGULATIONS.loc[:, 'end_regulations_HHMMSS'] = REGULATIONS.apply(lambda x: from_YYYYMMDDHHMMSS_to_HHMMSS(x.end_time.strip()), axis=1)

# %%
list_dates_with_regulations = REGULATIONS["date_DDMMYYYY"].values

start_regulations = REGULATIONS["start_regulations_HHMMSS"].values
end_regulations = REGULATIONS["end_regulations_HHMMSS"].values

list_volumes_regulations = REGULATIONS["traffic_volume"].values

# %%
list_days_from_regulations, \
start_time_samples_days_from_regulations, \
end_time_samples_days_from_regulations, \
volumes_days_from_regulations, \
labels_days_from_regulations = extract_days_timestamps_volumes_labels_days_with_regulations(list_dates_with_regulations, 
                                                                      start_regulations,
                                                                      end_regulations,
                                                                      list_volumes_regulations, 
                                                                      gap_before_start_time, 
                                                                      gap_after_start_time, 
                                                                      num_additional_samples_per_day=20,
                                                                      min_timestamps_with_regulations=10)

# %%
len(list_days_from_regulations), len(start_time_samples_days_from_regulations), \
len(end_time_samples_days_from_regulations), len(volumes_days_from_regulations)
# Out:
# (901, 901, 901, 901)

# %% [markdown]
# ### Extract all the features for the given dates and timestamps

# %%
list_days_without_regulations_extended = np.array(list_days_without_regulations_extended)
start_time_samples_no_regulations = np.array(start_time_samples_no_regulations)
end_time_samples_no_regulations = np.array(end_time_samples_no_regulations)
list_volumes_no_regulations = np.array(list_volumes_no_regulations)

# %%
X_days_without_regulations = np.zeros((len(list_days_without_regulations_extended), 
                                       int(gap_before_start_time+gap_after_start_time), 
                                       12))
X_days_without_regulations.shape
# Out:
# (71, 30, 12)

# %%
X_days_without_regulations = extract_features_from_list_days_and_timestamps(list_days_without_regulations_extended, 
                                                                           start_time_samples_no_regulations, 
                                                                           end_time_samples_no_regulations,
                                                                           list_volumes_no_regulations,
                                                                           gap_before_start_time, gap_after_start_time,
                                                                           X_days_without_regulations)
# Out:
# B3LL | counter: 1
# HWST | counter: 2
# HSOL | counter: 3
# B5WL | counter: 4
# B3EH | counter: 5
# B3LL | counter: 6
# HSOL | counter: 7
# BOLN | counter: 8
# B3LL | counter: 9
# DHOL | counter: 10
# B3LL | counter: 11
# H5RL | counter: 12
# HRHR | counter: 13
# HCEL | counter: 14
# D3WM | counter: 15
# HRHR | counter: 16
# D3WL | counter: 17
# DEST | counter: 18
# DHOL | counter: 19
# DHOL | counter: 20
# B3EH | counter: 21
# B3LL | counter: 22
# B5KL | counter: 23
# D3WL | counter: 24
# D3WM | counter: 25
# B3EH | counter: 26
# D3WL | counter: 27
# HRHR | counter: 28
# HCEL | counter: 29
# DHOL | counter: 30
# B5KL | counter: 31
# DHOL | counter: 32
# B3LL | counter: 33
# HRHR | counter: 34
# DJEV | counter: 35
# HCEL | counter: 36
# B5KL | counter: 37
# HMNS | counter: 38
# DHOL | counter: 39
# HEST | counter: 40
# B3EH | counter: 41
# HMNS | counter: 42
# HCEL | counter: 43
# HWST | counter: 44
# HSOL | counter: 45
# HSOL | counter: 46
# HRHR | counter: 47
# DHOL | counter: 48
# D3WM | counter: 49
# D3WL | counter: 50
# H5RL | counter: 51
# DJEV | counter: 52
# D3WL | counter: 53
# B3EH | counter: 54
# HRHR | counter: 55
# HRHR | counter: 56
# HRHR | counter: 57
# HMNS | counter: 58
# D3WL | counter: 59
# B5WH | counter: 60
# HRHR | counter: 61
# HRHR | counter: 62
# H5RL | counter: 63
# D5JL | counter: 64
# HRHR | counter: 65
# H5RL | counter: 66
# DHOL | counter: 67
# D6WH | counter: 68
# DHOL | counter: 69
# D3WL | counter: 70
# B5WH | counter: 71

# %%
np.save('./Counting_variables/X_days_without_regulations', X_days_without_regulations)

# %%
list_days_from_regulations = np.array(list_days_from_regulations)
start_time_samples_days_from_regulations = np.array(start_time_samples_days_from_regulations)
end_time_samples_days_from_regulations = np.array(end_time_samples_days_from_regulations)
volumes_days_from_regulations = np.array(volumes_days_from_regulations)

# %%
# Avoid a non existeing name of TV in our data
for i in range(len(volumes_days_from_regulations)):
    if volumes_days_from_regulations[i] == 'BALB':
        volumes_days_from_regulations[i] = 'BLUX'

# %%
X_days_from_regulations = np.zeros((len(list_days_from_regulations), 
                                    int(gap_before_start_time+gap_after_start_time), 
                                    12))
X_days_from_regulations.shape
# Out:
# (901, 30, 12)

# %%
X_days_from_regulations = extract_features_from_list_days_and_timestamps(list_days_from_regulations, 
                                                                       start_time_samples_days_from_regulations, 
                                                                       end_time_samples_days_from_regulations,
                                                                       volumes_days_from_regulations,
                                                                       gap_before_start_time, gap_after_start_time,
                                                                       X_days_from_regulations)
# Out:
# D3WLC | counter: 1
# D3WLC | counter: 2
# D3WLC | counter: 3
# D3WLC | counter: 4
# D3WLC | counter: 5
# D3WLC | counter: 6
# D3WLC | counter: 7
# D3WLC | counter: 8
# D6WH | counter: 9
# D6WH | counter: 10
# D6WH | counter: 11
# D6WH | counter: 12
# D6WH | counter: 13
# D6WH | counter: 14
# D6WH | counter: 15
# D6WH | counter: 16
# D6WH | counter: 17
# D6WH | counter: 18
# B5KL | counter: 19
# B5KL | counter: 20
# B5KL | counter: 21
# B3EH | counter: 22
# B3EH | counter: 23
# B3EH | counter: 24
# B3EH | counter: 25
# B3EH | counter: 26
# B3EH | counter: 27
# B3EH | counter: 28
# B3EH | counter: 29
# DJEV | counter: 30
# DJEV | counter: 31
# DJEV | counter: 32
# B3LL | counter: 33
# B3LL | counter: 34
# B3LL | counter: 35
# B3LL | counter: 36
# B3LL | counter: 37
# HCEL | counter: 38
# HCEL | counter: 39
# B3LL | counter: 40
# B3LL | counter: 41
# B3LL | counter: 42
# B3LL | counter: 43
# B3LL | counter: 44
# B3LL | counter: 45
# B3LL | counter: 46
# B3LL | counter: 47
# B3EH | counter: 48
# B3EH | counter: 49
# B3EH | counter: 50
# B3EH | counter: 51
# B3EH | counter: 52
# B3EH | counter: 53
# B5WL | counter: 54
# B5WL | counter: 55
# B5WL | counter: 56
# B5WL | counter: 57
# B5WL | counter: 58
# BEST | counter: 59
# BEST | counter: 60
# BEST | counter: 61
# BEST | counter: 62
# BEST | counter: 63
# BEST | counter: 64
# DHOL | counter: 65
# DHOL | counter: 66
# DHOL | counter: 67
# DHOL | counter: 68
# DHOL | counter: 69
# DHOL | counter: 70
# HMNS | counter: 71
# HMNS | counter: 72
# HMNS | counter: 73
# HMNS | counter: 74
# HRHR | counter: 75
# HSOL | counter: 76
# HSOL | counter: 77
# HSOL | counter: 78
# HSOL | counter: 79
# HSOL | counter: 80
# HSOL | counter: 81
# HSOL | counter: 82
# HSOL | counter: 83
# HRHR | counter: 84
# HRHR | counter: 85
# HRHR | counter: 86
# D3WLC | counter: 87
# D3WLC | counter: 88
# D3WLC | counter: 89
# D3WLC | counter: 90
# D3WLC | counter: 91
# D3WLC | counter: 92
# D3WM | counter: 93
# D3WM | counter: 94
# D3WM | counter: 95
# D3WM | counter: 96
# D3WM | counter: 97
# D3WM | counter: 98
# D3WM | counter: 99
# HCEL | counter: 100
# HCEL | counter: 101
# HCEL | counter: 102
# HCEL | counter: 103
# HCEL | counter: 104
# HSOL | counter: 105
# HSOL | counter: 106
# HSOL | counter: 107
# HSOL | counter: 108
# HSOL | counter: 109
# HSOL | counter: 110
# HSOL | counter: 111
# DHOL | counter: 112
# DHOL | counter: 113
# DHOL | counter: 114
# DHOL | counter: 115
# DHOL | counter: 116
# B3LH | counter: 117
# B3LH | counter: 118
# B3LH | counter: 119
# B3LL | counter: 120
# B3LL | counter: 121
# B3LL | counter: 122
# HSOL | counter: 123
# HSOL | counter: 124
# HSOL | counter: 125
# HSOL | counter: 126
# HSOL | counter: 127
# HSOL | counter: 128
# HSOL | counter: 129
# HSOL | counter: 130
# HCEL | counter: 131
# HCEL | counter: 132
# HCEL | counter: 133
# HCEL | counter: 134
# B5WL | counter: 135
# B5WL | counter: 136
# B5WL | counter: 137
# DJEV | counter: 138
# DJEV | counter: 139
# DJEV | counter: 140
# B3EH | counter: 141
# B3EH | counter: 142
# B3EH | counter: 143
# B3EH | counter: 144
# B3EH | counter: 145
# DHOL | counter: 146
# DHOL | counter: 147
# DHOL | counter: 148
# DHOL | counter: 149
# DHOL | counter: 150
# DHOL | counter: 151
# DHOL | counter: 152
# DHOL | counter: 153
# DHOL | counter: 154
# HRHR | counter: 155
# HRHR | counter: 156
# HRHR | counter: 157
# D3WM | counter: 158
# D3WM | counter: 159
# D3WM | counter: 160
# D3WM | counter: 161
# D3WM | counter: 162
# D3WM | counter: 163
# D3WM | counter: 164
# D3WM | counter: 165
# D3WM | counter: 166
# D3WM | counter: 167
# D3WM | counter: 168
# D3WM | counter: 169
# B3EH | counter: 170
# B3EH | counter: 171
# B3EH | counter: 172
# B3EH | counter: 173
# B3EH | counter: 174
# B3EH | counter: 175
# B3EH | counter: 176
# B3EH | counter: 177
# B3EH | counter: 178
# B3EH | counter: 179
# B3EH | counter: 180
# B3EH | counter: 181
# B3EH | counter: 182
# B3EH | counter: 183
# B3EH | counter: 184
# B3OL | counter: 185
# B3OL | counter: 186
# B3OL | counter: 187
# B3OL | counter: 188
# B3OL | counter: 189
# B3OL | counter: 190
# B3OL | counter: 191
# B3OL | counter: 192
# B3OL | counter: 193
# B3OL | counter: 194
# B3LL | counter: 195
# B3LL | counter: 196
# B3LL | counter: 197
# B3LL | counter: 198
# B3LL | counter: 199
# B3LL | counter: 200
# B3LL | counter: 201
# B3LL | counter: 202
# B3LL | counter: 203
# B3LL | counter: 204
# B3LL | counter: 205
# B3LL | counter: 206
# B3LL | counter: 207
# B3LL | counter: 208
# B3LL | counter: 209
# B3LL | counter: 210
# B3LL | counter: 211
# H5ML | counter: 212
# H5ML | counter: 213
# H5ML | counter: 214
# H5ML | counter: 215
# H5ML | counter: 216
# H5ML | counter: 217
# H5ML | counter: 218
# H5RL | counter: 219
# H5RL | counter: 220
# H5RL | counter: 221
# H5RL | counter: 222
# H5RL | counter: 223
# H5RL | counter: 224
# DJEV | counter: 225
# DJEV | counter: 226
# DJEV | counter: 227
# DJEV | counter: 228
# DJEV | counter: 229
# DJEV | counter: 230
# DJEV | counter: 231
# DJEV | counter: 232
# HRHR | counter: 233
# HRHR | counter: 234
# HRHR | counter: 235
# HRHR | counter: 236
# HRHR | counter: 237
# HRHR | counter: 238
# HRHR | counter: 239
# HRHR | counter: 240
# DHOL | counter: 241
# DHOL | counter: 242
# DHOL | counter: 243
# DHOL | counter: 244
# DHOL | counter: 245
# DHOL | counter: 246
# DHOL | counter: 247
# DHOL | counter: 248
# DHOL | counter: 249
# DHOL | counter: 250
# DHOL | counter: 251
# B5NL | counter: 252
# B5NL | counter: 253
# B5NL | counter: 254
# B5NL | counter: 255
# B5NL | counter: 256
# B5NL | counter: 257
# B5NL | counter: 258
# B5NL | counter: 259
# B5NL | counter: 260
# B5NL | counter: 261
# B5WH | counter: 262
# B5WH | counter: 263
# B5WH | counter: 264
# B5WH | counter: 265
# B5WH | counter: 266
# B5WH | counter: 267
# B5WH | counter: 268
# B5WH | counter: 269
# B5WH | counter: 270
# B5WH | counter: 271
# B5WH | counter: 272
# HRHR | counter: 273
# HRHR | counter: 274
# HRHR | counter: 275
# HRHR | counter: 276
# HRHR | counter: 277
# HRHR | counter: 278
# B3EH | counter: 279
# B3EH | counter: 280
# B3EH | counter: 281
# B3EH | counter: 282
# B3EH | counter: 283
# B3EH | counter: 284
# B3EH | counter: 285
# B3EH | counter: 286
# B3EH | counter: 287
# B3EH | counter: 288
# B3EH | counter: 289
# B3EH | counter: 290
# B3EH | counter: 291
# B3EH | counter: 292
# B5KL | counter: 293
# B5KL | counter: 294
# B5KL | counter: 295
# B5KL | counter: 296
# B5KL | counter: 297
# B5KL | counter: 298
# B5KL | counter: 299
# HSOL | counter: 300
# HSOL | counter: 301
# HSOL | counter: 302
# HSOL | counter: 303
# HSOL | counter: 304
# HSOL | counter: 305
# HSOL | counter: 306
# HSOL | counter: 307
# HSOL | counter: 308
# HCEL | counter: 309
# HCEL | counter: 310
# HCEL | counter: 311
# HCEL | counter: 312
# HCEL | counter: 313
# HCEL | counter: 314
# HCEL | counter: 315
# D6WH | counter: 316
# D6WH | counter: 317
# D6WH | counter: 318
# D6WH | counter: 319
# D6WH | counter: 320
# D6WH | counter: 321
# D6WH | counter: 322
# D6WH | counter: 323
# D6WH | counter: 324
# D6WH | counter: 325
# D6WH | counter: 326
# D3WM | counter: 327
# D3WM | counter: 328
# D3WM | counter: 329
# D3WM | counter: 330
# D3WM | counter: 331
# D3WM | counter: 332
# D3WM | counter: 333
# D3WL | counter: 334
# D3WL | counter: 335
# D3WL | counter: 336
# B3LL | counter: 337
# B3LL | counter: 338
# B3LL | counter: 339
# B3LL | counter: 340
# B3LL | counter: 341
# B3LL | counter: 342
# B3LL | counter: 343
# B3LL | counter: 344
# B3LL | counter: 345
# B3LL | counter: 346
# B3LL | counter: 347
# B3LL | counter: 348
# HRHR | counter: 349
# HRHR | counter: 350
# HRHR | counter: 351
# HRHR | counter: 352
# HRHR | counter: 353
# HRHR | counter: 354
# HRHR | counter: 355
# HRHR | counter: 356
# HRHR | counter: 357
# D3WLC | counter: 358
# D3WLC | counter: 359
# D3WLC | counter: 360
# D3WLC | counter: 361
# D3WLC | counter: 362
# D3WLC | counter: 363
# D3WLC | counter: 364
# D3WLC | counter: 365
# D3WLC | counter: 366
# D5JL | counter: 367
# D5JL | counter: 368
# D5JL | counter: 369
# D5JL | counter: 370
# D5JL | counter: 371
# B5WL | counter: 372
# B5WL | counter: 373
# B5WL | counter: 374
# B5WL | counter: 375
# B5WL | counter: 376
# B5WL | counter: 377
# HEST | counter: 378
# HEST | counter: 379
# HEST | counter: 380
# HEST | counter: 381
# HEST | counter: 382
# DEST | counter: 383
# DEST | counter: 384
# DEST | counter: 385
# DEST | counter: 386
# DEST | counter: 387
# DEST | counter: 388
# BOLN | counter: 389
# BOLN | counter: 390
# BOLN | counter: 391
# BOLN | counter: 392
# BOLN | counter: 393
# BOLN | counter: 394
# BWST | counter: 395
# BWST | counter: 396
# BWST | counter: 397
# BWST | counter: 398
# BWST | counter: 399
# BWST | counter: 400
# D3WM | counter: 401
# D3WM | counter: 402
# D3WL | counter: 403
# D3WL | counter: 404
# D3WL | counter: 405
# D3WL | counter: 406
# HSOL | counter: 407
# HSOL | counter: 408
# HSOL | counter: 409
# HSOL | counter: 410
# HSOL | counter: 411
# HSOL | counter: 412
# HSOL | counter: 413
# B3LL | counter: 414
# B3LL | counter: 415
# B3LL | counter: 416
# B3LL | counter: 417
# B3EH | counter: 418
# B3EH | counter: 419
# B3EH | counter: 420
# B3EH | counter: 421
# B3EH | counter: 422
# B3EH | counter: 423
# HRHR | counter: 424
# HRHR | counter: 425
# HRHR | counter: 426
# HRHR | counter: 427
# HRHR | counter: 428
# HMNS | counter: 429
# HMNS | counter: 430
# HMNS | counter: 431
# HMNS | counter: 432
# HMNS | counter: 433
# HSOL | counter: 434
# HSOL | counter: 435
# HSOL | counter: 436
# HSOL | counter: 437
# HSOL | counter: 438
# HSOL | counter: 439
# HSOL | counter: 440
# HSOL | counter: 441
# HSOL | counter: 442
# H5RL | counter: 443
# H5RL | counter: 444
# H5RL | counter: 445
# H5RL | counter: 446
# H5ML | counter: 447
# H5ML | counter: 448
# H5ML | counter: 449
# H5ML | counter: 450
# H5WH | counter: 451
# H5WH | counter: 452
# H5WH | counter: 453
# H5WH | counter: 454
# H5WH | counter: 455
# H5WH | counter: 456
# DJEV | counter: 457
# DJEV | counter: 458
# DJEV | counter: 459
# DJEV | counter: 460
# DJEV | counter: 461
# DJEV | counter: 462
# DJEV | counter: 463
# DJEV | counter: 464
# HWST | counter: 465
# HWST | counter: 466
# HWST | counter: 467
# DHOL | counter: 468
# DHOL | counter: 469
# DHOL | counter: 470
# DHOL | counter: 471
# DHOL | counter: 472
# DHOL | counter: 473
# DHOL | counter: 474
# DHOL | counter: 475
# DHOL | counter: 476
# B5KL | counter: 477
# B5KL | counter: 478
# B5KL | counter: 479
# B5KL | counter: 480
# B5KL | counter: 481
# B5KL | counter: 482
# B5KL | counter: 483
# B5KL | counter: 484
# D3WL | counter: 485
# D3WL | counter: 486
# D3WL | counter: 487
# D3WL | counter: 488
# D3WL | counter: 489
# D3WL | counter: 490
# D3WM | counter: 491
# D3WM | counter: 492
# D3WM | counter: 493
# D3WM | counter: 494
# D3WM | counter: 495
# D3WM | counter: 496
# D3WM | counter: 497
# D3WM | counter: 498
# B5KL | counter: 499
# B5KL | counter: 500
# B5KL | counter: 501
# B5KL | counter: 502
# B5KL | counter: 503
# B5KL | counter: 504
# B5KL | counter: 505
# B5KL | counter: 506
# B5KL | counter: 507
# HMNS | counter: 508
# HMNS | counter: 509
# HMNS | counter: 510
# HMNS | counter: 511
# HMNS | counter: 512
# HRHR | counter: 513
# HRHR | counter: 514
# HRHR | counter: 515
# HRHR | counter: 516
# HRHR | counter: 517
# HRHR | counter: 518
# HRHR | counter: 519
# HRHR | counter: 520
# HRHR | counter: 521
# HRHR | counter: 522
# DJEV | counter: 523
# DJEV | counter: 524
# DJEV | counter: 525
# DJEV | counter: 526
# DJEV | counter: 527
# DJEV | counter: 528
# DJEV | counter: 529
# DJEV | counter: 530
# DJEV | counter: 531
# DHOL | counter: 532
# DHOL | counter: 533
# DHOL | counter: 534
# DHOL | counter: 535
# DHOL | counter: 536
# DHOL | counter: 537
# DHOL | counter: 538
# DHOL | counter: 539
# HSOL | counter: 540
# HSOL | counter: 541
# HSOL | counter: 542
# HSOL | counter: 543
# HSOL | counter: 544
# D3WLC | counter: 545
# D3WLC | counter: 546
# D3WLC | counter: 547
# D3WLC | counter: 548
# D3WM | counter: 549
# D3WM | counter: 550
# D3WM | counter: 551
# D3WM | counter: 552
# D3WM | counter: 553
# B3EH | counter: 554
# B3EH | counter: 555
# B3EH | counter: 556
# B3EH | counter: 557
# B3EH | counter: 558
# BOLN | counter: 559
# BOLN | counter: 560
# BOLN | counter: 561
# BOLN | counter: 562
# BOLN | counter: 563
# BOLN | counter: 564
# BOLN | counter: 565
# BOLN | counter: 566
# BOLN | counter: 567
# HRHR | counter: 568
# HRHR | counter: 569
# HRHR | counter: 570
# HRHR | counter: 571
# HRHR | counter: 572
# HRHR | counter: 573
# D3WLC | counter: 574
# D3WLC | counter: 575
# D3WLC | counter: 576
# D3WLC | counter: 577
# D3WLC | counter: 578
# B5WL | counter: 579
# B5WL | counter: 580
# B5WL | counter: 581
# B5WL | counter: 582
# B5WL | counter: 583
# B5KL | counter: 584
# B5KL | counter: 585
# D6WH | counter: 586
# D6WH | counter: 587
# D6WH | counter: 588
# D6WH | counter: 589
# D6WH | counter: 590
# D6WH | counter: 591
# BOLN | counter: 592
# BOLN | counter: 593
# BOLN | counter: 594
# BOLN | counter: 595
# BOLN | counter: 596
# BOLN | counter: 597
# BOLN | counter: 598
# D3WM | counter: 599
# D3WM | counter: 600
# D3WM | counter: 601
# D3WM | counter: 602
# D3WM | counter: 603
# H5RL | counter: 604
# H5RL | counter: 605
# H5RL | counter: 606
# H5RL | counter: 607
# H5RL | counter: 608
# D3WLC | counter: 609
# D3WLC | counter: 610
# B5WL | counter: 611
# B5WL | counter: 612
# B5WL | counter: 613
# B5WL | counter: 614
# B5WL | counter: 615
# D3WM | counter: 616
# D3WM | counter: 617
# D3WM | counter: 618
# D3WM | counter: 619
# HRHR | counter: 620
# HRHR | counter: 621
# HRHR | counter: 622
# HRHR | counter: 623
# HRHR | counter: 624
# HRHR | counter: 625
# HRHR | counter: 626
# HRHR | counter: 627
# HRHR | counter: 628
# HRHR | counter: 629
# HRHR | counter: 630
# HRHR | counter: 631
# HRHR | counter: 632
# B5KL | counter: 633
# B5KL | counter: 634
# B5KL | counter: 635
# B5KL | counter: 636
# B5KL | counter: 637
# BOLN | counter: 638
# BOLN | counter: 639
# BOLN | counter: 640
# BOLN | counter: 641
# BOLN | counter: 642
# BOLN | counter: 643
# BOLN | counter: 644
# HRHR | counter: 645
# HRHR | counter: 646
# HRHR | counter: 647
# HRHR | counter: 648
# HRHR | counter: 649
# HRHR | counter: 650
# HRHR | counter: 651
# HRHR | counter: 652
# HRHR | counter: 653
# HRHR | counter: 654
# HRHR | counter: 655
# B3LL | counter: 656
# B3LL | counter: 657
# B3LL | counter: 658
# B3LL | counter: 659
# B3LL | counter: 660
# B3LL | counter: 661
# B3LL | counter: 662
# B3LL | counter: 663
# HMNS | counter: 664
# HMNS | counter: 665
# HMNS | counter: 666
# HMNS | counter: 667
# HMNS | counter: 668
# HMNS | counter: 669
# HMNS | counter: 670
# HMNS | counter: 671
# HMNS | counter: 672
# HSOL | counter: 673
# HSOL | counter: 674
# HSOL | counter: 675
# HSOL | counter: 676
# BOLN | counter: 677
# BOLN | counter: 678
# BOLN | counter: 679
# BOLN | counter: 680
# BOLN | counter: 681
# BOLN | counter: 682
# BOLN | counter: 683
# BOLN | counter: 684
# BOLN | counter: 685
# BOLN | counter: 686
# BOLN | counter: 687
# HSOL | counter: 688
# HSOL | counter: 689
# HSOL | counter: 690
# HSOL | counter: 691
# B3EH | counter: 692
# B3EH | counter: 693
# B3EH | counter: 694
# B3EH | counter: 695
# B3EH | counter: 696
# B3EH | counter: 697
# B3EH | counter: 698
# B3EH | counter: 699
# B3EH | counter: 700
# B3EH | counter: 701
# B3EH | counter: 702
# B3EH | counter: 703
# B3OL | counter: 704
# B3OL | counter: 705
# B3OL | counter: 706
# B3OL | counter: 707
# B3OL | counter: 708
# B3OL | counter: 709
# B3OL | counter: 710
# B3OL | counter: 711
# B3OL | counter: 712
# B3LL | counter: 713
# B3LL | counter: 714
# B3LL | counter: 715
# B3LL | counter: 716
# B3LL | counter: 717
# B3LL | counter: 718
# B3LL | counter: 719
# B3LL | counter: 720
# B3LL | counter: 721
# B3LL | counter: 722
# B3LL | counter: 723
# B3LL | counter: 724
# B3LL | counter: 725
# HSOL | counter: 726
# HSOL | counter: 727
# HSOL | counter: 728
# HSOL | counter: 729
# HSOL | counter: 730
# HSOL | counter: 731
# HRHR | counter: 732
# HRHR | counter: 733
# HRHR | counter: 734
# HRHR | counter: 735
# HRHR | counter: 736
# HRHR | counter: 737
# B3LL | counter: 738
# B3LL | counter: 739
# B3LL | counter: 740
# B3LL | counter: 741
# B3LL | counter: 742
# B3LL | counter: 743
# B3LL | counter: 744
# B3OL | counter: 745
# B3OL | counter: 746
# B3OL | counter: 747
# B3OL | counter: 748
# HCEL | counter: 749
# HCEL | counter: 750
# HCEL | counter: 751
# DJEV | counter: 752
# DJEV | counter: 753
# DJEV | counter: 754
# DJEV | counter: 755
# DJEV | counter: 756
# DHOL | counter: 757
# DHOL | counter: 758
# DHOL | counter: 759
# DHOL | counter: 760
# DHOL | counter: 761
# HRHR | counter: 762
# HRHR | counter: 763
# HRHR | counter: 764
# HMNS | counter: 765
# HMNS | counter: 766
# HMNS | counter: 767
# HMNS | counter: 768
# HMNS | counter: 769
# HMNS | counter: 770
# HMNS | counter: 771
# HMNS | counter: 772
# D6WH | counter: 773
# D6WH | counter: 774
# D6WH | counter: 775
# D6WH | counter: 776
# D6WH | counter: 777
# D6WH | counter: 778
# D6WH | counter: 779
# D6WH | counter: 780
# D3WLC | counter: 781
# D3WLC | counter: 782
# D3WLC | counter: 783
# DHOL | counter: 784
# DHOL | counter: 785
# DHOL | counter: 786
# DHOL | counter: 787
# DHOL | counter: 788
# DHOL | counter: 789
# DHOL | counter: 790
# DHOL | counter: 791
# DHOL | counter: 792
# D6WH | counter: 793
# D6WH | counter: 794
# D6WH | counter: 795
# D6WH | counter: 796
# D6WH | counter: 797
# D6WH | counter: 798
# D6WH | counter: 799
# D6WH | counter: 800
# B5WL | counter: 801
# B5WL | counter: 802
# B5WL | counter: 803
# B5WL | counter: 804
# B5WL | counter: 805
# B5WL | counter: 806
# B5WL | counter: 807
# B5WL | counter: 808
# B5WL | counter: 809
# D3WLC | counter: 810
# D3WLC | counter: 811
# D3WLC | counter: 812
# D3WLC | counter: 813
# D3WLC | counter: 814
# D3WLC | counter: 815
# D3WLC | counter: 816
# D3WLC | counter: 817
# D3WLC | counter: 818
# HRHR | counter: 819
# HRHR | counter: 820
# HRHR | counter: 821
# HRHR | counter: 822
# HRHR | counter: 823
# HRHR | counter: 824
# DJEV | counter: 825
# DJEV | counter: 826
# DJEV | counter: 827
# DJEV | counter: 828
# DJEV | counter: 829
# DJEV | counter: 830
# DJEV | counter: 831
# DJEV | counter: 832
# HMNS | counter: 833
# HMNS | counter: 834
# HMNS | counter: 835
# HMNS | counter: 836
# BOLN | counter: 837
# BOLN | counter: 838
# BOLN | counter: 839
# BOLN | counter: 840
# BOLN | counter: 841
# BOLN | counter: 842
# BOLN | counter: 843
# BLUX | counter: 844
# BLUX | counter: 845
# BLUX | counter: 846
# BLUX | counter: 847
# BLUX | counter: 848
# B3LL | counter: 849
# B3LL | counter: 850
# B3LL | counter: 851
# B3LL | counter: 852
# B3LL | counter: 853
# B3LL | counter: 854
# B3LL | counter: 855
# B3LL | counter: 856
# B3LL | counter: 857
# B3LH | counter: 858
# B3LH | counter: 859
# B3LH | counter: 860
# B3LH | counter: 861
# B3LH | counter: 862
# B3LH | counter: 863
# B3LH | counter: 864
# B3LH | counter: 865
# B3LH | counter: 866
# BOLN | counter: 867
# BOLN | counter: 868
# BOLN | counter: 869
# BOLN | counter: 870
# BOLN | counter: 871
# BOLN | counter: 872
# D3WLC | counter: 873
# D3WLC | counter: 874
# D3WLC | counter: 875
# D3WLC | counter: 876
# D3WLC | counter: 877
# D3WLC | counter: 878
# D3WLC | counter: 879
# D6WH | counter: 880
# D6WH | counter: 881
# D6WH | counter: 882
# D6WH | counter: 883
# D6WH | counter: 884
# HRHR | counter: 885
# HRHR | counter: 886
# HRHR | counter: 887
# HRHR | counter: 888
# HRHR | counter: 889
# HRHR | counter: 890
# DEST | counter: 891
# DEST | counter: 892
# DEST | counter: 893
# DEST | counter: 894
# DEST | counter: 895
# DEST | counter: 896
# HWST | counter: 897
# HWST | counter: 898
# HWST | counter: 899
# HWST | counter: 900
# DWST | counter: 901

# %%
np.save('./Counting_variables/X_days_from_regulations', X_days_from_regulations)
np.save('./Counting_variables/labels_days_from_regulations', labels_days_from_regulations)

# %% [markdown]
# # Extract the weather features

# %%
X_days_without_regulations_weather = np.zeros((len(list_days_without_regulations_extended), 
                                               int(gap_before_start_time+gap_after_start_time), 
                                               num_weather_features*num_metric_per_weather_feature))
X_days_without_regulations_weather.shape
# Out:
# (71, 30, 48)

# %%
X_days_without_regulations_weather = extract_weather_information_from_list_days_and_timestamps(
    list_days_without_regulations_extended, 
    start_time_samples_no_regulations, 
    end_time_samples_no_regulations,
    list_volumes_no_regulations,
    num_weather_features,
    num_metric_per_weather_feature,
    X_days_without_regulations_weather)
# Out:
# day: 08/06/2019 | start:130900 | TV: B3LL
# day: 09/06/2019 | start:040400 | TV: HWST
# day: 16/06/2019 | start:062300 | TV: HSOL
# day: 17/06/2019 | start:191300 | TV: B5WL
# day: 18/06/2019 | start:052700 | TV: B3EH
# day: 21/06/2019 | start:051500 | TV: B3LL
# day: 22/06/2019 | start:202700 | TV: HSOL
# day: 23/06/2019 | start:210700 | TV: BOLN
# day: 24/06/2019 | start:210300 | TV: B3LL
# day: 25/06/2019 | start:041400 | TV: DHOL
# day: 26/06/2019 | start:205400 | TV: B3LL
# day: 27/06/2019 | start:122600 | TV: H5RL
# day: 31/08/2019 | start:093100 | TV: BOLN
# day: 31/08/2019 | start:194700 | TV: BOLN
# day: 31/08/2019 | start:201900 | TV: D3WLC
# day: 31/08/2019 | start:184600 | TV: D3WLC
# day: 31/08/2019 | start:193300 | TV: D3WLC
# day: 31/08/2019 | start:193500 | TV: D3WLC
# day: 31/08/2019 | start:042800 | TV: D3WLC
# day: 31/08/2019 | start:131300 | TV: D3WLC
# day: 31/08/2019 | start:183800 | TV: D3WLC
# day: 31/08/2019 | start:171900 | TV: D6WH
# day: 31/08/2019 | start:184900 | TV: D6WH
# day: 31/08/2019 | start:191700 | TV: D6WH
# day: 31/08/2019 | start:094600 | TV: D6WH
# day: 31/08/2019 | start:053000 | TV: D6WH
# day: 31/08/2019 | start:172300 | TV: HRHR
# day: 31/08/2019 | start:123500 | TV: HRHR
# day: 31/08/2019 | start:112100 | TV: HRHR
# day: 31/08/2019 | start:193100 | TV: HRHR
# day: 31/08/2019 | start:093400 | TV: HRHR
# day: 31/08/2019 | start:071800 | TV: HRHR
# day: 31/08/2019 | start:203100 | TV: DEST
# day: 31/08/2019 | start:122600 | TV: DEST
# day: 31/08/2019 | start:062200 | TV: DEST
# day: 31/08/2019 | start:052400 | TV: DEST
# day: 31/08/2019 | start:163100 | TV: DEST
# day: 31/08/2019 | start:194200 | TV: DEST
# day: 31/08/2019 | start:204500 | TV: HWST
# day: 31/08/2019 | start:211700 | TV: HWST
# day: 31/08/2019 | start:212600 | TV: HWST
# day: 31/08/2019 | start:061900 | TV: HWST
# day: 31/08/2019 | start:202100 | TV: DWST

# %%
np.save('./Counting_variables/X_days_from_regulations_weather', X_days_from_regulations_weather)

# %% [markdown]
# # Concatenate the scalar variables and the weather features

# %%
X_days_without_regulations = np.load('./Counting_variables/X_days_without_regulations.npy')
X_days_without_regulations_weather = np.load('./Counting_variables/X_days_without_regulations_weather.npy')

X_days_from_regulations = np.load('./Counting_variables/X_days_from_regulations.npy')
X_days_from_regulations_weather = np.load('./Counting_variables/X_days_from_regulations_weather.npy')

labels_days_from_regulations = np.load('./Counting_variables/labels_days_from_regulations.npy')

# %%
X_days_without_regulations_concatenate = np.zeros((X_days_without_regulations.shape[0], 
                                                   X_days_without_regulations.shape[1],
                                                   X_days_without_regulations.shape[2]+X_days_without_regulations_weather.shape[2]))

X_days_without_regulations_concatenate.shape
# Out:
# (71, 30, 60)

# %%
X_days_without_regulations_concatenate[:,:,0:num_weather_features*num_metric_per_weather_feature] = X_days_without_regulations_weather
X_days_without_regulations_concatenate[:,:,num_weather_features*num_metric_per_weather_feature:] = X_days_without_regulations

# %%
X_days_from_regulations_concatenate = np.zeros((X_days_from_regulations.shape[0], 
                                                X_days_from_regulations.shape[1],
                                                X_days_from_regulations.shape[2]+X_days_from_regulations_weather.shape[2]))

X_days_from_regulations_concatenate.shape
# Out:
# (901, 30, 60)

# %%
X_days_from_regulations_concatenate[:,:,0:num_weather_features*num_metric_per_weather_feature] = X_days_from_regulations_weather
X_days_from_regulations_concatenate[:,:,num_weather_features*num_metric_per_weather_feature:] = X_days_from_regulations

# %% [markdown]
# # Create the labels

# %%
Y_days_without_regulations = np.zeros((X_days_without_regulations_concatenate.shape[0], (gap_before_start_time+gap_after_start_time), 1), dtype=int)

# %%
Y_days_without_regulations.shape
# Out:
# (71, 30, 1)

# %%
Y_from_regulations = np.zeros((X_days_from_regulations_concatenate.shape[0], (gap_before_start_time+gap_after_start_time), 1), dtype=int)

# %%
Y_from_regulations = labels_days_from_regulations

# %%
Y_from_regulations.shape
# Out:
# (901, 30, 1)

# %% [markdown]
# # Split into training & testing - By day

# %%
X_train = np.concatenate((X_days_without_regulations_concatenate,
                          X_days_from_regulations_concatenate))

y_train = np.concatenate((Y_days_without_regulations,
                          Y_from_regulations))

# %%
X_train.shape, y_train.shape
# Out:
# ((972, 30, 60), (972, 30, 1))

# %%
# np.save('./Counting_variables/All_TVs_randomSamples_splitByDays/X_train', X_train)
# np.save('./Counting_variables/All_TVs_randomSamples_splitByDays/y_train', y_train)
# np.save('./Counting_variables/All_TVs_randomSamples_splitByDays/X_test', X_test)
# np.save('./Counting_variables/All_TVs_randomSamples_splitByDays/y_test', y_test)

# %% [markdown]
# # Only using the max values form the weather features

# %%
# Delete the min and avg values
list_weather_features_delete = []
for i in range(num_weather_features):
    list_weather_features_delete.append(0+i*num_metric_per_weather_feature)
    list_weather_features_delete.append(1+i*num_metric_per_weather_feature)
    
# Additional elements added to the delete list
list_weather_features_delete.append(1*3-1)
list_weather_features_delete.append(3*3-1)

# list_weather_features_delete.append(4*3-1)
# list_weather_features_delete.append(11*3-1)
# list_weather_features_delete.append(3*3-1)
# list_weather_features_delete.append(3*3-1)

# %%
X_train_del = np.zeros((X_train.shape[0], X_train.shape[1], X_train.shape[2]-len(list_weather_features_delete)))

for j in range(X_train.shape[0]):
    X_train_del[j] = np.delete(X_train[j], list_weather_features_delete, axis=1)

# %%
X_train_del.shape
# Out:
# (972, 30, 26)

# %%
# Used it to avoid having to change the name of the variables in the following lines
X_train = X_train_del

# %% [markdown]
# # Train the model

# %%
from keras.layers import BatchNormalization
from keras.models import Sequential

# %%
def Hotspoter_v2(input_shape):

    daily_traffic = Input(shape=input_shape)
    
    X = LSTM(X_train.shape[2]*2, return_sequences=True)(daily_traffic)
    X = Dropout(0.5)(X)
    X =  BatchNormalization()(X)

    X = LSTM(X_train.shape[2]*3, return_sequences = True)(X)
    X = Dropout(0.5)(X)
    X =  BatchNormalization()(X)
    
#     X = LSTM(X_train.shape[2]*2, return_sequences = True)(X)
#     X = Dropout(0.5)(X)
#     X =  BatchNormalization()(X)
    
#     X = LSTM(X_train.shape[2]*4, return_sequences = True)(X)
#     X = Dropout(0.5)(X)
#     X =  BatchNormalization()(X)

    X = LSTM(X_train.shape[2], return_sequences = True)(X)
    X = Dropout(0.5)(X)
    X =  BatchNormalization()(X)
    
    X = TimeDistributed(Dense(1, activation = "sigmoid"))(X) # time distributed  (sigmoid)
    
    model = Model(inputs=daily_traffic, outputs=X)

    
    return model

# %%
num_timestamps_per_sample = gap_before_start_time + gap_after_start_time

model = Hotspoter_v2((num_timestamps_per_sample, X_train.shape[2]))

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 30, 26)]          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 30, 52)            16432
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 52)            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 52)            208
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 78)            40872
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 78)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 78)            312
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 26)            10920
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 26)            0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 26)            104
# _________________________________________________________________
# time_distributed (TimeDistri (None, 30, 1)             27
# =================================================================
# Total params: 68,875
# Trainable params: 68,563
# Non-trainable params: 312
# _________________________________________________________________

# %%
# Anopther option: sparse_categorical_crossentropy
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, 
                    validation_data = (X_train, y_train),
                    epochs = 200, batch_size = batch_size, shuffle=True)
# Out:
# Epoch 1/200
# 31/31 [==============================] - 1s 32ms/step - loss: 0.7402 - accuracy: 0.5976 - val_loss: 0.6649 - val_accuracy: 0.5866
# Epoch 2/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.6711 - accuracy: 0.6487 - val_loss: 0.6386 - val_accuracy: 0.6440
# Epoch 3/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.6574 - accuracy: 0.6566 - val_loss: 0.6084 - val_accuracy: 0.6898
# Epoch 4/200
# 31/31 [==============================] - 1s 19ms/step - loss: 0.6236 - accuracy: 0.6802 - val_loss: 0.5762 - val_accuracy: 0.7324
# Epoch 5/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.5930 - accuracy: 0.7061 - val_loss: 0.5550 - val_accuracy: 0.7334
# Epoch 6/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.5765 - accuracy: 0.7165 - val_loss: 0.5263 - val_accuracy: 0.7538
# Epoch 7/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.5794 - accuracy: 0.7156 - val_loss: 0.5194 - val_accuracy: 0.7601
# Epoch 8/200
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5699 - accuracy: 0.7135 - val_loss: 0.5005 - val_accuracy: 0.7683
# Epoch 9/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.5577 - accuracy: 0.7276 - val_loss: 0.4875 - val_accuracy: 0.7685
# Epoch 10/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.5457 - accuracy: 0.7308 - val_loss: 0.5004 - val_accuracy: 0.7693
# Epoch 11/200
# 31/31 [==============================] - 1s 18ms/step - loss: 0.5396 - accuracy: 0.7346 - val_loss: 0.4797 - val_accuracy: 0.7733
# Epoch 12/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.5442 - accuracy: 0.7334 - val_loss: 0.4817 - val_accuracy: 0.7832
# Epoch 13/200
# 31/31 [==============================] - 0s 15ms/step - loss: 0.5398 - accuracy: 0.7346 - val_loss: 0.4647 - val_accuracy: 0.7850
# Epoch 14/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.5331 - accuracy: 0.7346 - val_loss: 0.4795 - val_accuracy: 0.7777
# Epoch 15/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.5102 - accuracy: 0.7487 - val_loss: 0.4779 - val_accuracy: 0.7761
# Epoch 16/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.5312 - accuracy: 0.7484 - val_loss: 0.4808 - val_accuracy: 0.7659
# Epoch 17/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.5217 - accuracy: 0.7458 - val_loss: 0.4823 - val_accuracy: 0.7822
# Epoch 18/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.5082 - accuracy: 0.7617 - val_loss: 0.4681 - val_accuracy: 0.7770
# Epoch 19/200
# 31/31 [==============================] - 1s 17ms/step - loss: 0.5238 - accuracy: 0.7472 - val_loss: 0.4841 - val_accuracy: 0.7628
# Epoch 20/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.5195 - accuracy: 0.7517 - val_loss: 0.4605 - val_accuracy: 0.7838
# Epoch 21/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.5027 - accuracy: 0.7678 - val_loss: 0.4557 - val_accuracy: 0.7968
# Epoch 22/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.5021 - accuracy: 0.7630 - val_loss: 0.4591 - val_accuracy: 0.7956
# Epoch 23/200
# 31/31 [==============================] - 0s 13ms/step - loss: 0.4881 - accuracy: 0.7727 - val_loss: 0.4542 - val_accuracy: 0.7919
# Epoch 24/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.
200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.3338 - accuracy: 0.8548 - val_loss: 0.2219 - val_accuracy: 0.9088
# Epoch 179/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3311 - accuracy: 0.8546 - val_loss: 0.2831 - val_accuracy: 0.8792
# Epoch 180/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3315 - accuracy: 0.8601 - val_loss: 0.2541 - val_accuracy: 0.8942
# Epoch 181/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3257 - accuracy: 0.8608 - val_loss: 0.2516 - val_accuracy: 0.8952
# Epoch 182/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.3221 - accuracy: 0.8617 - val_loss: 0.2369 - val_accuracy: 0.9007
# Epoch 183/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.3169 - accuracy: 0.8651 - val_loss: 0.2791 - val_accuracy: 0.8855
# Epoch 184/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3511 - accuracy: 0.8480 - val_loss: 0.2359 - val_accuracy: 0.9044
# Epoch 185/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3532 - accuracy: 0.8449 - val_loss: 0.3309 - val_accuracy: 0.8604
# Epoch 186/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3307 - accuracy: 0.8562 - val_loss: 0.2526 - val_accuracy: 0.8927
# Epoch 187/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.3487 - accuracy: 0.8448 - val_loss: 0.2698 - val_accuracy: 0.8879
# Epoch 188/200
# 31/31 [==============================] - 0s 9ms/step - loss: 0.3179 - accuracy: 0.8595 - val_loss: 0.2459 - val_accuracy: 0.8974
# Epoch 189/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3116 - accuracy: 0.8723 - val_loss: 0.2526 - val_accuracy: 0.8907
# Epoch 190/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3510 - accuracy: 0.8493 - val_loss: 0.2840 - val_accuracy: 0.8755
# Epoch 191/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3448 - accuracy: 0.8465 - val_loss: 0.2569 - val_accuracy: 0.8878
# Epoch 192/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3259 - accuracy: 0.8610 - val_loss: 0.2610 - val_accuracy: 0.8886
# Epoch 193/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.3389 - accuracy: 0.8529 - val_loss: 0.2756 - val_accuracy: 0.8809
# Epoch 194/200
# 31/31 [==============================] - 0s 12ms/step - loss: 0.3238 - accuracy: 0.8579 - val_loss: 0.2530 - val_accuracy: 0.8938
# Epoch 195/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3283 - accuracy: 0.8526 - val_loss: 0.2633 - val_accuracy: 0.8859
# Epoch 196/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3119 - accuracy: 0.8577 - val_loss: 0.2442 - val_accuracy: 0.8991
# Epoch 197/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3165 - accuracy: 0.8610 - val_loss: 0.2516 - val_accuracy: 0.8889
# Epoch 198/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.3147 - accuracy: 0.8641 - val_loss: 0.2108 - val_accuracy: 0.9129
# Epoch 199/200
# 31/31 [==============================] - 0s 11ms/step - loss: 0.3302 - accuracy: 0.8561 - val_loss: 0.2979 - val_accuracy: 0.8840
# Epoch 200/200
# 31/31 [==============================] - 0s 10ms/step - loss: 0.3374 - accuracy: 0.8526 - val_loss: 0.2960 - val_accuracy: 0.8697

# %%
plt.rcParams['figure.figsize'] = [12, 7]

fig, axs = plt.subplots(nrows=1, ncols=2)
axs[0].plot(history.history['loss'], 'r', linewidth=3.0) 
axs[0].plot(history.history['val_loss'], 'b', linewidth=3.0)
axs[0].legend(['train_loss', 'val_loss'], fontsize=10)
axs[0].set_xlabel('Epochs ', fontsize=12)
axs[0].set_ylabel('Loss', fontsize=12)
axs[0].set_ylim(0,10)
axs[0].set_title('Loss', fontsize=12)

axs[1].plot(history.history['accuracy'], 'r', linewidth=3.0) 
axs[1].plot(history.history['val_accuracy'], 'b', linewidth=3.0)
axs[1].legend(['train_accuracy', 'val_accuracy'], fontsize=10)
axs[1].set_xlabel('Epochs ', fontsize=12)
axs[1].set_ylabel('Precision', fontsize=12) 
axs[1].set_ylim(0,1.2)
axs[1].set_title('Accuracy', fontsize=12)
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
from metrics import confusion_matrix_sequencialOutput, confusion_matrix_sequencial_output_mean_std

# %% [markdown]
# ### Training samples

# %%
TP, FP, TN, FN, conf_matrix = confusion_matrix_sequencialOutput(model, 
                                                                X_train, y_train, 
                                                                (gap_before_start_time + gap_after_start_time))

# %%
conf_matrix
# Out:
# array([[15405.,  3120.],
#        [  680.,  9955.]])

# %%
print("Accuracy trainng: %.2f" % ((TP+TN)/(TP+FP+FN+TN)*100) + "%")
print("Recall trainng: %.2f" % (TP/(TP+FN)*100) + "%")
print("Precicion trainng: %.2f" % (TP/(TP+FP)*100) + "%")
# Out:
# Accuracy trainng: 86.97%
# Recall trainng: 95.77%
# Precicion trainng: 83.16%

# %% [markdown]
# # Analysing similaritis

# %%
from metrics import similarity_sequential_output_percentage_correct

# %%
equal, similar, incorrect = similarity_sequential_output_percentage_correct(model, X_train, y_train, 80)
# Out:
# /home/sergi/Documents/PhD_UPC/RNN_v8_muac_weather/metrics.py:248: RuntimeWarning: divide by zero encountered in true_divide
#   percentage_correct_predictions = sum_prediction / sum_test_sample
# /home/sergi/Documents/PhD_UPC/RNN_v8_muac_weather/metrics.py:248: RuntimeWarning: invalid value encountered in true_divide
#   percentage_correct_predictions = sum_prediction / sum_test_sample

# %%
equal, similar, incorrect
# Out:
# (0.6635802469135802, 0.2932098765432099, 0.043209876543209874)

# %% [markdown]
# # From many-to-many to many-to-one

# %%
from metrics import detect_regulations_binary, updated_detect_regulations_binary, updated_detect_regulations_binary_mean_std

# %%
TP_binary, FP_binary, TN_binary, FN_binary, conf_matrix_binary = detect_regulations_binary(model, X_train, y_train)

# %%
conf_matrix_binary
# Out:
# array([[576.,  87.],
#        [  0., 225.]])

# %%
print("Accuracy testing: %.2f" % ((TP_binary+TN_binary)/(TP_binary+FP_binary+FN_binary+TN_binary)*100) + "%")
print("Recall testing: %.2f" % (TP_binary/(TP_binary+FN_binary)*100) + "%")
print("Precicion testing: %.2f" % (TP_binary/(TP_binary+FP_binary)*100) + "%")
# Out:
# Accuracy testing: 90.20%
# Recall testing: 100.00%
# Precicion testing: 86.88%

# %%
TP_binary, FP_binary, TN_binary, FN_binary, conf_matrix_binary = updated_detect_regulations_binary(model, 
                                                                                                   X_train, 
                                                                                                   y_train, 10)

# %%
conf_matrix_binary
# Out:
# array([[549.,  88.],
#        [ 19., 316.]])

# %%
print("Accuracy testing: %.2f" % ((TP_binary+TN_binary)/(TP_binary+FP_binary+FN_binary+TN_binary)*100) + "%")
print("Recall testing: %.2f" % (TP_binary/(TP_binary+FN_binary)*100) + "%")
print("Precicion testing: %.2f" % (TP_binary/(TP_binary+FP_binary)*100) + "%")
# Out:
# Accuracy testing: 88.99%
# Recall testing: 96.65%
# Precicion testing: 86.19%

# %% [markdown]
# # Saving the model

# %%
# model.save('./Counting_variables/Generic_model_weather_MUAC_integration.h5')
